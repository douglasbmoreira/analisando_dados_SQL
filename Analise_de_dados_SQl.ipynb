# %% [markdown]
# <a href="https://colab.research.google.com/github/douglasbmoreira/analisando_dados_SQL/blob/main/Analise_de_dados_SQl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Alt text: Slogan da Meteora.](https://i.imgur.com/VDYh2G1.png)

# %% [markdown]
# # 1. Estruturando a tabela

# %% [markdown]
# **Meteora** é uma loja que vende roupas e acessórios de diversas marcas por todos os estados do Brasil, para entender suas bases de dados e exibir informações relevantes com o objetivo de auxiliar suas tomadas de decisão.

# %%
#Importando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, inspect, text

# %% [markdown]
# **Sobre as tabelas**
#
# * itens_pedidos: tabela que informa sobre o que foi vendido, vai ter informação o preço, quantidade, para onde vai ser enviado e o frete do pedido
# * pedidos: vai falar sobre a venda feita, tendo informação sobre os vendedores, preço do pedido e a data da venda
# * produtos: informa características dos produtos que são comercializados na loja
# * vendedores: informa o nome dos vendedores.

# %%
#Criando variáveis para os links que contém dos dados
url_itens_pedidos = 'https://github.com/alura-cursos/SQL-python-integracao/raw/main/TABELAS/itens_pedidos.csv'
url_pedidos = 'https://github.com/alura-cursos/SQL-python-integracao/raw/main/TABELAS/pedidos.csv'
url_produto = 'https://github.com/alura-cursos/SQL-python-integracao/raw/main/TABELAS/produtos.csv'
url_vendedores = 'https://github.com/alura-cursos/SQL-python-integracao/raw/main/TABELAS/vendedores.csv'

# %%
#Criando variáveis e lendo os dados com o Pandas
itens_pedidos = pd.read_csv(url_itens_pedidos)
pedidos = pd.read_csv(url_pedidos)
produtos = pd.read_csv(url_produto)
vendedores = pd.read_csv(url_vendedores)

# %%
#Criando um ambiente virtual para ler os dados SQL
engine = create_engine('sqlite:///memory:')

# %%
#Lendo os dados da tabela Produtos em SQL
produtos.to_sql('produtos',engine,index=False)
# Out:
# 205

# %%
#Lendo os dados das tabelas em SQL
itens_pedidos.to_sql('itens_pedidos', engine, index=False)
pedidos.to_sql('pedidos', engine, index=False)
vendedores.to_sql('vendedores', engine, index=False)
# Out:
# 5

# %%
#Inspecionando os nomes das tabelas, e verificando se esta funcionando o engine
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['itens_pedidos', 'pedidos', 'produtos', 'vendedores']

# %% [markdown]
# # 2. Primeiras consultas

# %% [markdown]
# Vamos entender a característica do produto que é comercializadora na Meteora, analisando a **condição** dos produtos vendidos.

# %%
#Criando uma variavel chamda 'query' para obter as condições dos produtos
query = 'SELECT CONDICAO FROM PRODUTOS'

# %%
#Criando um dataframe com as condições dos produtos
with engine.connect() as conexao:
  consulta = conexao.execute(text(query))
  dados = consulta.fetchall()
pd.DataFrame(dados, columns = consulta.keys())
# Out:
#               Condicao
# 0                Usado
# 1                Usado
# 2                Usado
# 3                Usado
# 4                Usado
# ..                 ...
# 200              Usado
# 201              Usado
# 202              Usado
# 203              Usado
# 204  Novo com etiqueta
#
# [205 rows x 1 columns]

# %%
#Criando uma função para pesquisar de forma mais rápida
def sql_df(query):
  with engine.connect() as conexao:
    consulta = conexao.execute(text(query))
    dados = consulta.fetchall()
  return pd.DataFrame(dados, columns = consulta.keys())

# %%
#Aplicando a função que criamos
sql_df(query)
# Out:
#               Condicao
# 0                Usado
# 1                Usado
# 2                Usado
# 3                Usado
# 4                Usado
# ..                 ...
# 200              Usado
# 201              Usado
# 202              Usado
# 203              Usado
# 204  Novo com etiqueta
#
# [205 rows x 1 columns]

# %%
#Criando uma variável 'query' para obter a condições dos produtos e agrupar na coluna 'Quantidade' a soma dos produtos
query = "SELECT CONDICAO, COUNT(*) AS 'Quantidade' FROM PRODUTOS GROUP BY CONDICAO"

#Criando uma váriavel para armazenar os dados obtidos com a query
df_produtos= sql_df(query)
df_produtos
# Out:
#             Condicao  Quantidade
# 0  Novo com etiqueta          22
# 1  Novo sem etiqueta           7
# 2              Usado         176

# %%
#Plotando gráfico de barras usando o Matplotlib os dados obtidos no
plt.bar(df_produtos['Condicao'], df_produtos['Quantidade'])

#Adicionando título ao gráfico
plt.title('Contagem por tipo de condição dos produtos')
plt.show()

# %% [markdown]
# Agora precisamos ranquear os produtos que mais foram pedidos por **quantidade** para entender a necessidade de um estoque de produtos na loja.

# %%
#Selecionando os produtos e visualizando os 3 primeiros com a função head()
sql_df('SELECT * FROM PRODUTOS').head(3)
# Out:
#    produto_id               produto  preco                marca     sku  \
# 0       21244  Oculos Lente Azulada   1120  D&g Dolce & Gabbana  209297
# 1        9981      Bolsa Coral Saco   4000             Givenchy  278612
# 2       84176   Camisa Xadrez Verde    310            Joe Fresh  322482
#
#   Condicao
# 0    Usado
# 1    Usado
# 2    Usado

# %%
#Selecionando os itens pedidos e visualizando os 3 primeiros com a função head()
sql_df('SELECT * FROM ITENS_PEDIDOS').head(3)
# Out:
#    id_nf  produto_id  pedido_id  quantidade  valor_unitario  valor_total  \
# 0      1       41518        341           3             260          780
# 1      2        4307       1174           5            6175        30875
# 2      3       22407       1399           3             200          600
#
#   Estado   frete
# 0  BR-BA   156.0
# 1  BR-RJ  6175.0
# 2  BR-PB   120.0

# %% [markdown]
# Após a visualização percebemos que ambas as tabelas tem uma coluna com mesmo nome 'produto_id' usaremos essa coluna para unir as tabelas e obter os produtos mais pedidos

# %%
#Escrevendo a query pedindo para selecionar a coluna Produto_id na tabela Itens_pedidos, e coluna Produto na tabela Produtos, e somar a quantidade
#de itens pedidos e colocar na coluna 'Quantidade', obtendo os dados da tabelas, usando como paramêtro as colunas 'Produto_id' das duas tabelas,
#agrupando por Produto, e em ordem crescente
query = '''SELECT ITENS_PEDIDOS.PRODUTO_ID, PRODUTOS.PRODUTO, SUM(ITENS_PEDIDOS.QUANTIDADE) AS Quantidade
FROM ITENS_PEDIDOS, PRODUTOS
WHERE ITENS_PEDIDOS.PRODUTO_ID = PRODUTOS.PRODUTO_ID
GROUP BY PRODUTOS.PRODUTO
ORDER BY Quantidade ASC'''

df_prod_quant= sql_df(query)
df_prod_quant
# Out:
#      produto_id                  produto  Quantidade
# 0         47682    Vestido Malha Estampa         318
# 1         84743     Blusa Listrada Malha         322
# 2         88368         Blusa Malha Azul         325
# 3         32986  Blusa Babados Off-white         337
# 4          2706              Blusa Cinza         341
# ..          ...                      ...         ...
# 196       32126          Saia Midi Cinto         549
# 197       11218  Calca Alfaiataria Preta         750
# 198       72667        Saia Pregas Preta         751
# 199       98640     Calca Jeans Costuras         755
# 200       15875   Vestido Recortes Cores         795
#
# [201 rows x 3 columns]

# %%
#Plotando um gráfico de barras horizontais dos produtos mais pedidos
plt.barh(df_prod_quant['produto'][-10:], df_prod_quant['Quantidade'][-10:], color= '#9353FF')
plt.xlabel('Quantidade vendida')
plt.show()

# %% [markdown]
# # 3. Lidando com filtro

# %% [markdown]
# Vamos iniciar uma análise de desempenho do **time de vendedores** da Meteora. A intenção aqui é entender como se deram as vendas dos vendedores no **ano anterior** para que possam ser aplicadas promoções e bônus salarial para a equipe no ano atual da tabela que é 2021

# %%
#Filtrando os pedidos
sql_df('SELECT * FROM PEDIDOS').head(3)
# Out:
#    pedido_id  produto_id  vendedor_id data_compra  total
# 0        341       41518            5  2019-01-05    780
# 1       1174        4307            3  2019-01-05  30875
# 2       1399       22407            1  2019-01-05    600

# %%
#Entendendo quais tipos de dados estamos trabalhando
sql_df('SELECT * FROM PEDIDOS').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24527 entries, 0 to 24526
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pedido_id    24527 non-null  int64
#  1   produto_id   24527 non-null  int64
#  2   vendedor_id  24527 non-null  int64
#  3   data_compra  24527 non-null  object
#  4   total        24527 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 958.2+ KB

# %%
#Selecionando as vendas por vendedores e agrupando elas para saver o total de vendas por vendedor no ano de 2020
query = '''SELECT VENDEDOR_ID, COUNT(*)
FROM PEDIDOS
WHERE strftime('%Y',data_compra) = '2020'
GROUP BY VENDEDOR_ID
'''
sql_df(query)
# Out:
#    vendedor_id  COUNT(*)
# 0            1      3427
# 1            2      3338
# 2            3      2782
# 3            4      2510
# 4            5      2488

# %% [markdown]
# Para entender o desempenho de vendas dos vendedores no ano de 2020, é preciso trabalhar com os dados que estão presentes apenas no ano de 2020.

# %%
#Agrupando os dados de vendas do ano de 2020 e em conjunto com a tabela 'Vendedores' e a colina 'vendedores_id' vamos descobrir os nomes dos vendedores
#ao combinar a tabela 'Pedidos' que tem a coluna 'vendedor_id', e ordenadores em ordem descrecente
query = '''SELECT VENDEDORES.NOME_VENDEDOR, COUNT (PEDIDOS.PEDIDO_ID)
AS 'Quantidade vendas'
FROM PEDIDOS, VENDEDORES
WHERE strftime ('%Y', data_compra) = '2020' AND VENDEDORES.VENDEDOR_ID = PEDIDOS.VENDEDOR_ID
GROUP BY VENDEDORES.NOME_VENDEDOR
ORDER BY COUNT (PEDIDOS.PEDIDO_ID) DESC '''

sql_df(query)
# Out:
#      nome_vendedor  Quantidade vendas
# 0       Ana Duarte               3427
# 1  Daniel Siqueira               3338
# 2   Nadia Oliveira               2782
# 3  Millena Pereira               2510
# 4    Paulo Calanca               2488

# %%
#Calculando a média da quantidade de vendas de cada vendedor no ano de 2020
query = '''SELECT VENDEDORES.NOME_VENDEDOR, AVG(PEDIDOS.TOTAL)
AS 'Quantidade vendas'
FROM PEDIDOS, VENDEDORES
WHERE strftime ('%Y', data_compra) = '2020' AND VENDEDORES.VENDEDOR_ID = PEDIDOS.VENDEDOR_ID
GROUP BY VENDEDORES.NOME_VENDEDOR
ORDER BY AVG(PEDIDOS.TOTAL) DESC '''

sql_df(query)
# Out:
#      nome_vendedor  Quantidade vendas
# 0  Daniel Siqueira        1972.338526
# 1  Millena Pereira        1894.614343
# 2       Ana Duarte        1843.452582
# 3   Nadia Oliveira        1818.342200
# 4    Paulo Calanca        1813.469855

# %% [markdown]
# # 4. Avançando nas relações

# %% [markdown]
# A Meteora agora deseja incrementar as suas vendas no **estado de São Paulo (SP)**, por acreditar ser uma região mais propícia às vendas já que tem uma boa concentração de pessoas e mercado também.
#
# Mas será que São Paulo já não rende muitas vendas em relação a outros estados?

# %%
#Rankeando as vendas soma de vendas por estados do Brasil
query= '''SELECT ESTADO, COUNT(*) AS Pedidos
FROM ITENS_PEDIDOS
GROUP BY ESTADO
ORDER BY Pedidos DESC
'''

sql_df(query)
# Out:
#    Estado  Pedidos
# 0   BR-MA      974
# 1   BR-DF      953
# 2   BR-MT      937
# 3   BR-GO      933
# 4   BR-PA      932
# 5   BR-AL      928
# 6   BR-PE      927
# 7   BR-RR      925
# 8   BR-RO      925
# 9   BR-RN      921
# 10  BR-PI      919
# 11  BR-RJ      918
# 12  BR-PB      918
# 13  BR-RS      910
# 14  BR-MG      908
# 15  BR-SE      907
# 16  BR-PR      903
# 17  BR-TO      899
# 18  BR-ES      895
# 19  BR-BA      894
# 20  BR-SP      890
# 21  BR-SC      886
# 22  BR-CE      883
# 23  BR-AP      873
# 24  BR-MS      865
# 25  BR-AC      861
# 26  BR-AM      843

# %% [markdown]
# Uma das ações que a Meteora pretende seguir para as vendas em SP é escolher dois de seus vendedores para que eles **foquem suas vendas** lá. Para essa escolha é interessante ter os profissionais que **mais tenham vendido** para as pessoas da região.

# %%
#Filtrando os vendedores que mais fizeram vendas para clientes do estado de São Paulo, e colocando em ordem descrecente
query = '''SELECT VENDEDORES.NOME_VENDEDOR, COUNT(*) AS quantidade_vendas
FROM PEDIDOS
JOIN VENDEDORES ON VENDEDORES.VENDEDOR_ID = PEDIDOS.VENDEDOR_ID
JOIN ITENS_PEDIDOS ON ITENS_PEDIDOS.PEDIDO_ID = PEDIDOS.PEDIDO_ID
WHERE ITENS_PEDIDOS.ESTADO = 'BR-SP'
GROUP BY VENDEDORES.NOME_VENDEDOR
ORDER BY quantidade_vendas DESC
'''

sql_df(query)
# Out:
#      nome_vendedor  quantidade_vendas
# 0  Daniel Siqueira                190
# 1    Paulo Calanca                182
# 2   Nadia Oliveira                181
# 3       Ana Duarte                180
# 4  Millena Pereira                157
